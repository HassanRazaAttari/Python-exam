# %%
list1 = [1234,"Acura" , " Honda Motor Company" ,
         2011 , 25676 , "12 - 03 - 11" , "blue" ,
         "Abdul Rehman" , "karachi" , 500]

list2 = [2378 ,"Bmw" ,  " Bmw groups " ,
         2011 , 25676 , "12 - 04 - 11" , "red" ,
         "hassan" , "lahore" , 700]

list3 = [8709 ,"toyota" ,  " toyota Company" ,
         2011 , 25676 , "02 - 03 - 11" , "white" ,
         "Ahmed" , "Peshawar" , 10000]

list4 = [1543 ,"Ferrari" ,  " My Company" ,
         2011 , 25676 , "18 - 03 - 11" , "green" ,
         "Faizan" , "Islamabad" , 4567]

list5 = [2309 ,"cultus" ,  " suzuki Company" ,
         2011 , 25676 , "19 - 01 - 11" , "black" ,
         "Bilal" , "Quetta" , 1324]

# %%
f = open('abc.txt','w')
for i in list1:
    f.write(str(i)+'\n')
f.close()




f = open('abc.txt','a+')
for i in list2:
    f.write(str(i)+'\n')
f.close()    


f = open('abc.txt','a+')
for i in list3:
    f.write(str(i)+'\n')
f.close()    




f = open('abc.txt','a+')
for i in list4:
    f.write(str(i)+'\n')
f.close()    

f = open('abc.txt','a+')
for i in list5:
    f.write(str(i)+'\n')
f.close()

# %%
val2 = input("enter how many cars you want to purchase:")

data = []
val2 = int(val2)
i = val2
while i!=0:
    ids = input("enter ID of car you want to purchase:")
    ids = int(ids)
    data += [ids]
    i = i-1
    
    

   
price = 0
for z in range(len(data)):
    if data[z] == list1[0]:
        price += ((list1[len(list1) -1]))
    
        
    elif data[z] == list2[0]:
        price += ((list2[len(list2) -1]))
    
    elif data[z] == list3[0]:
        price += ((list3[len(list3) -1]))
    
    elif data[z] == list4[0]:
        price += ((list4[len(list4) -1]))
    
    elif data[z] == list5[0]:
        price += ((list5[len(list5) -1]))
    
        
print("Total price = ", price)
discounted_price = 0
discount = 20
if val2 > 1:
    discounted_price = price - (price * discount / 100)
    print ("Discounted price is = ",discounted_price)
else:
    discounted_price = price
    print ("Discounted price is = ",discounted_price)
# Out:
# enter how many cars you want to purchase:2
# enter ID of car you want to purchase:1234
# enter ID of car you want to purchase:2378
# Total price =  1200
# Discounted price is =  960.0

# %% [markdown]
# ### drop down tkinter

# %%
from tkinter import *

root = Tk()
root.title('CAR AUTOMATION SYSTEM')
root.geometry("400x400")

def selected(event):
    mylabel = Label(root, text = clicked.get()).pack()
    if clicked.get() == "Acura":
        mylabel = Label(root, text=list1).pack()
        
        f = open('pqr.txt','a+')
        for i in list1:
            f.write(str(i)+'\n')
        f.close()    
    
        
    elif clicked.get() == "Bmw":
        mylabel = Label(root, text=list2).pack()
        
        
        f = open('pqr.txt','a+')
        for i in list2:
            f.write(str(i)+'\n')
        f.close()    
    
        
    elif clicked.get() == "Ferrari":
        mylabel = Label(root, text=list3).pack()
        
        f = open('pqr.txt','a+')
        for i in list3:
                f.write(str(i)+'\n')
        f.close()    
    
        
    elif clicked.get() == "Toyota":
        mylabel = Label(root, text=list4).pack()
        
        f = open('pqr.txt','a+')
        for i in list4:
            f.write(str(i)+'\n')
        f.close()    
    
        
        
    elif clicked.get() == "cultus":
        mylabel = Label(root, text=list5).pack()
        f = open('pqr.txt','a+')
        for i in list5:
            f.write(str(i)+'\n')
        f.close()    
        

options = [
    "Acura",
    "Bmw",
    "Ferrari",
    "Toyota",
    "cultus",
]

clicked = StringVar()
clicked.set(options[0])

drop  = OptionMenu(root, clicked, *options, command=selected)
drop.pack(pady=50)
            

root.mainloop()
